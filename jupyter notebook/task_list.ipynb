# %% [markdown]
# # Список тренировочных задач

# %% [markdown]
# В данном разделе курса мы представим большой список тренировочных задач по каждой из пройденных тем. Мы предлагаем вам реализовать каждую задачу как средствами библиотеки pandas, так и на SQL. После каждого условия задачи будет представлен целевой вид итоговых данных. Наши варианты решения задач вы сможете найти в этом же разделе в конце. Каждая задача имеет свой порядковый номер, по которому будет удобно искать соответствующий ответ.
#
# В процессе решения задач вам совершенно не обязательно концентрироваться лишь на тех инструментах, которые мы рассматриваем в нашем курсе, помните о том, что у вас есть полная свобода действий, самое главное - получить верный результат. Также отметим, что и в наших вариантах решений мы позволяли себе использовать различные методы (особенно это касается pandas), описание которых было опущено в теле курса. Пусть вас не смущает этот факт, ведь одним из самых эффективных способов обучение является упорная работа над практическими задачами и самостоятельный поиск информации, в процессе которого вы постоянно будете осваивать новые навыки.

# %% [markdown]
# ### Map операции

# %% [markdown]
# #### 1.1

# %% [markdown]
# В таблице order_details есть поле discount_price, оно хранит данные о стоимости на позицию товара в чеке с учетом скидки, при этом в одной позиции может быть несколько товаров, следовательно, столбец discount_price содержит итоговую стоимость всех товаров в позиции. Получите новый вычислямый столбец, котором будет расчитана цена за 1 товар с учетом скидки.

# %% [markdown]
# ![image.png](attachment:db69ff1d-214c-449b-af26-e8a36d791ae5.png)

# %% [markdown]
# #### 1.2

# %% [markdown]
# Создайте новый вычисляемый столбец в таблице customers, который будет хранить данные о диапазонах возрастов клиентов. Возраст расчитайте относительно даты, в которую вы решаете данную задачу. Используйте следующие рамки для расчета диапазонов:
#
#  - 18 - 24 года
#  - 25 - 34 года
#  - 35 - 44 года
#  - 45 - 54 года
#  - 55 и более

# %% [markdown]
# ![image.png](attachment:373132cd-539d-4f0b-a554-e20aa1173567.png)

# %% [markdown]
# #### 1.3

# %% [markdown]
# В таблице сотрудников магазина salesmen создайте два вычисляемых поля, в одном должно храниться имя сотрудника, в другом - фамилия.

# %% [markdown]
# ![image.png](attachment:744f2f1a-747c-48f1-9c29-706dc44de939.png)

# %% [markdown]
# #### 1.4

# %% [markdown]
# В таблице orders создайте новое поле, хранящее информацию о годе и номере квартала каждого заказа.

# %% [markdown]
# ![image.png](attachment:7d55943c-cec2-4688-b7ab-7e868d46baa8.png)

# %% [markdown]
# #### 1.5

# %% [markdown]
# В таблице order_details в новом столбце рассчитайте сумму скидки в процентах на каждую позицию товаров, результат округлите с точность до 1 знака после запятой.

# %% [markdown]
# ![image.png](attachment:45ed3c54-b495-4aac-8fe0-6bb21484677a.png)

# %% [markdown]
# #### 1.6

# %% [markdown]
# Создайте новый вычисляемый столбец в таблице products с классификацией товаров в зависимости от их цены. Использйте следующие диапазоны:
#
#  - цена до 10 000 (невключительно) - класс "low price"
#  - цена от 10 000 (включительно) до 100 000 (невключительно) - класс "medium price"
#  - цена от 100 000 (включительно) и выше - класс "high price"

# %% [markdown]
# ![image.png](attachment:0321064c-f9e1-49c4-961a-83b251c7eb10.png)

# %% [markdown]
# ### Операции фильтрации

# %% [markdown]
# #### 2.1

# %% [markdown]
# Из таблицы orders получите такие заказы, которые были сделаны в течении 1 квартала 2023 года.

# %% [markdown]
# ![image.png](attachment:634050e3-4511-422a-a1b2-4694efab3b3b.png)

# %% [markdown]
# #### 2.2

# %% [markdown]
# Из таблицы products выведите товары, цена которых находится в диапазоне от 50 000 до 100 000.

# %% [markdown]
# ![image.png](attachment:72c3192e-bf86-4309-9977-e427c7a3b226.png)

# %% [markdown]
# #### 2.3

# %% [markdown]
# Выведите из таблицы stores список магазинов, расположенных в Москве и относящихся к классу "grand".

# %% [markdown]
# ![image.png](attachment:f4771a30-b477-43c6-a7ef-9d3c2ffc54c1.png)

# %% [markdown]
# #### 2.4

# %% [markdown]
# Из таблицы order_details выведите все записи по товарам из следующего списка:
#
#  - (1105042d-9197-4bcd-9668-bb5ab2a76221, 2487e34e-728d-4d0b-818b-45f8f111f853, b5355c21-48ad-42e7-9ee6-ebe9085881a3)

# %% [markdown]
# ![image.png](attachment:693ec858-07a3-4d0a-b8f7-30ef89f771da.png)

# %% [markdown]
# #### 2.5

# %% [markdown]
# Из таблицы customers выведите всех клиентов, имя которых начинается на букву А и имеет 5 и более букв в своем составе.

# %% [markdown]
# ![image.png](attachment:0be00336-99c9-4b9c-b1d3-3bc85c8bdee0.png)

# %% [markdown]
# #### 2.6

# %% [markdown]
# Выведите всех клиентов, фамилии которых заканчивают на буквы "в" или "н", при этом email таких клиентов должен заканчиваться на "@gmail.com" (таблица customers).

# %% [markdown]
# ![image.png](attachment:ede741d8-e0df-4bc7-9071-15bb3a7a7497.png)

# %% [markdown]
# #### 2.7

# %% [markdown]
# Получите список магазинов, площадь которых составляет не более 300 кв.м, при этом находящихся в одном из городов (Москва, Ульяновск, Волгоград), или же таких магазинов, класс которых является grand или mini, при этом расположенных на какой-либо аллее (в начале адреса присутствует сокращение алл.) (таблица stores).

# %% [markdown]
# ![image.png](attachment:15a8caaa-32a0-4059-bc70-5b6deff10a68.png)

# %% [markdown]
# #### 2.8

# %% [markdown]
# Из таблицы orders получите такие заказы, количество товаров которых находится в рамках от 2 до 5 штук, сумма чека с учетом скидки не превышает 100 000, также заказ должен быть сделан в 2022 году.

# %% [markdown]
# ![image.png](attachment:f6c317ee-fe05-40db-ba6b-948b7c9ef4e4.png)

# %% [markdown]
# #### 2.9

# %% [markdown]
# Из таблицы order_details выведите данные по чекам, в которых каждая позиция содержит не менее 2 товаров, базовая стоимость позиции товара находится в пределах от 100 до 300 тысяч. Еще одним условием является то, что в позициях не должно быть товаров из данного списка:
# (
# bd7e5101-71be-4935-b3e5-324636baecd6,
# 9088aa9a-3248-4f1a-ab3d-5527e4cd6521,
# 6febba3f-5ba3-428e-904f-048d9fd76897,
# 4864ff98-69e3-4fa5-95c9-a5d35c4cdaa5,
# 96e9a531-230e-4237-8011-da09df534aaa,
# a720c029-0703-4120-9559-99243fe5f2b1,
# fcec9f7c-1c9e-4669-87ce-a207713349e7
# )

# %% [markdown]
# ![image.png](attachment:81565403-e6a3-42bc-aa95-1fcd00512c32.png)

# %% [markdown]
# ### Операции группировки, транспонирования

# %% [markdown]
# #### 3.1

# %% [markdown]
# Посчитайте общее количество, проданных товаров за все время, общую сумму выручки с учетом и без учета скидки и общее количество уникальных заказов (таблица orders).

# %% [markdown]
# #### 3.2

# %% [markdown]
# Посчитайте количество уникальных клиентов магазина (таблица customers или таблица orders).

# %% [markdown]
# #### 3.3

# %% [markdown]
# Рассчитайте продажи (суммарное количество проданных товаров), сумму выручки с учетом скидки, максимальное и минимальное количество товаров в чеке и среднюю сумму чека без учета скидки с группировкой по датам заказов (таблица orders).

# %% [markdown]
# ![image.png](attachment:225519f0-150e-4a37-a4f5-9d330817bf8d.png)

# %% [markdown]
# #### 3.4

# %% [markdown]
# Рассчитайте количество сотрудников в каждой должности (таблица salesmen).

# %% [markdown]
# ![image.png](attachment:2bdec2e4-7fdb-4da2-94d7-c1f539e10233.png)

# %% [markdown]
# #### 3.5

# %% [markdown]
# Посчитайте сумму выручки и продажи с группировкой по датам и идентификаторам магазинов (таблица orders).

# %% [markdown]
# ![image.png](attachment:64f5c3b0-0e0f-421d-a6fc-d0502e95b790.png)

# %% [markdown]
# #### 3.6

# %% [markdown]
# Выведите количество товаров по каждому бренду и категории (можно использовать идентификаторы brand_id и category_id) (таблица products).

# %% [markdown]
# ![image.png](attachment:e275be74-17b1-4d91-8588-4abd0b2e3b0c.png)

# %% [markdown]
# #### 3.7

# %% [markdown]
# Какое количество заказов сделал каждый клиент за все время? Получите также максимальную и минимальную сумму чека по каждому клиенту за всю историю заказов (таблица orders).

# %% [markdown]
# ![image.png](attachment:4ddfc999-ab5f-4e19-83ff-72cc4f47ee23.png)

# %% [markdown]
# #### 3.8

# %% [markdown]
# Скольких уникальных клиентов обслужил каждый сотрудник магазина? (таблица orders).

# %% [markdown]
# ![image.png](attachment:893069ad-f340-4993-9314-4262118ebb46.png)

# %% [markdown]
# #### 3.9

# %% [markdown]
# Сколько было продано в штуках каждого товара за всю историю? (таблица order_details).

# %% [markdown]
# ![image.png](attachment:05b2ee72-82da-4b0b-9f0f-a5512cb5317a.png)

# %% [markdown]
# ### Операции join

# %% [markdown]
# #### 4.1

# %% [markdown]
# Проведите операцию внутреннего соединения между таблицами products, brands и categories.

# %% [markdown]
# ![image.png](attachment:8b0a50da-65e5-4a3b-a39b-50791c84b108.png)

# %% [markdown]
# #### 4.2

# %% [markdown]
# Расширьте атрибутный состав таблицы orders так, чтобы иметь доступ к адресам и классам магазинов.

# %% [markdown]
# ![image.png](attachment:ea0f8b04-3194-465e-8b87-1234f43df424.png)

# %% [markdown]
# #### 4.3

# %% [markdown]
# Получите только такие заказы для каждого клиента, которые были сделаны в его день рождения. Также можете реализовать чуть более сложный вариант данной задачи, а именно, выведите такие заказы для каждого клиента, которые были сделаны в период за 5 дней до и за 5 дней после дня рождения клиента.

# %% [markdown]
# ![image.png](attachment:9de3fd9b-ba6e-43cf-8cc0-d79e5e0d88e4.png)

# %% [markdown]
# #### 4.4

# %% [markdown]
# Получите только такие заказы, которые были сделаны в день устройства сотрудника на работу.

# %% [markdown]
# ![image.png](attachment:8d39907e-3c34-4a59-b0a3-d7d8ce48a4cf.png)

# %% [markdown]
# #### 4.5

# %% [markdown]
# Проведите операцию внутреннего соединения для всех таблиц нашей тренировочной модели данных.

# %% [markdown]
# #### 4.6

# %% [markdown]
# Получите список клиентов, у которых день рождения (день и месяц) совпадает с днем и месяцем устройства на работу хотя бы 1 сотрудника из штата магазинов.

# %% [markdown]
# ![image.png](attachment:18309a0d-21b7-414d-a399-0d0e753e85f5.png)

# %% [markdown]
# ### Операции конкатенации

# %% [markdown]
# #### 5.1

# %% [markdown]
# Используя операцию со множествами, проверьте, есть ли такие клиенты, которые ни разу не делали никаких заказов за всю историю.

# %% [markdown]
# #### 5.2

# %% [markdown]
# С помощью операции со множествами получите список имен и фамилий клиентов и сотрудников, исключив при этом дублирующиеся записи.

# %% [markdown]
# #### 5.3

# %% [markdown]
# Через операцию со множествами получите список имен и фамилий, которые совпадают у клиентов и сотрудников сети.

# %% [markdown]
# ### Операции сортировки

# %% [markdown]
# #### 6.1

# %% [markdown]
# Получите таблицу со списком клиентов, отсортированную по дате рождения по возрастанию

# %% [markdown]
# ![image.png](attachment:044471b7-8722-4123-981f-a6a1b5f31103.png)

# %% [markdown]
# #### 6.2

# %% [markdown]
# Получите таблицу со списком сотрудников, отсортировав данные по дате устройства на работу по возрастанию и по имени и фамилии по убыванию.

# %% [markdown]
# ![image.png](attachment:0ced0ed6-646a-4f71-8a8f-00167a44e36e.png)

# %% [markdown]
# #### 6.3

# %% [markdown]
# Выведите данные из таблицы products, отсортировав их по цене и названию товара по убыванию.

# %% [markdown]
# ![image.png](attachment:975f0aa3-65dd-47de-8e19-60e001b50a9a.png)

# %% [markdown]
# ### Оконные функции, накопительный итог

# %% [markdown]
# #### 7.1

# %% [markdown]
# В таблице products создайте новый столбец, показывающий в каждой строке общее количество уникальных товаров, продающихся в сети магазинов.

# %% [markdown]
# ![image.png](attachment:e82ac98d-9b55-4b5a-ac29-1f9a35e2c651.png)

# %% [markdown]
# #### 7.2

# %% [markdown]
# В таблице products напротив каждого бренда проставьте среднюю цену составляющих его товаров, гранулярность таблицы products не должна измениться.

# %% [markdown]
# ![image.png](attachment:8b944bf6-797a-485d-bb4c-09f0f8c6a0b1.png)

# %% [markdown]
# #### 7.3

# %% [markdown]
# Теперь добавьте разбивку также по категории, иными словами, рассчитайте среднюю цену товаров, входящих в каждый бренд каждой категории. Гранулярность таблицы products не должна измениться.

# %% [markdown]
# ![image.png](attachment:087349b1-2bf0-44b2-a8ba-9d6cfa374491.png)

# %% [markdown]
# #### 7.4

# %% [markdown]
# В таблице orders напротив каждого клиента получите общее количество его заказов за всю историю, при этом гранулярность таблицы не должна измениться.

# %% [markdown]
# ![image.png](attachment:ab590d82-ea17-4c48-b691-3662cbf4a3f2.png)

# %% [markdown]
# #### 7.5

# %% [markdown]
# По каждому сотруднику магазинов в таблице orders рассчитайте максимальную сумму чека с учетом скидки среди когда-либо оформленных заказов, гранулярность таблицы orders не должна измениться.

# %% [markdown]
# ![image.png](attachment:3cd1ae80-e166-4401-ad28-5198fead5dec.png)

# %% [markdown]
# #### 7.6

# %% [markdown]
# По каждому клиенту в таблице orders расчитайте накопительную сумму чеков по его заказам (с учетом скидки), отсортировав даты покупок по возрастанию.

# %% [markdown]
# ![image.png](attachment:e7507ebf-fcc5-47a4-9959-3517b85cc1b0.png)

# %% [markdown]
# #### 7.7

# %% [markdown]
# В таблице stores проранжируйте магазины в зависимости от их площади. Самый большой по площади магазин должен получить ранг 1, если площадь у магазинов совпадает, то они должны получить одинаковые ранги, а последующие магазины ранг по порядку (без перескакивания).

# %% [markdown]
# ![image.png](attachment:b71a18fc-7383-4a82-becf-f19bd0caf8ba.png)

# %% [markdown]
# #### 7.8

# %% [markdown]
# В таблице orders проранжируйте заказы для каждого клиента, отсортировав покупки по возрастанию даты. Иными словами, первый заказ должен получить ранг 1, если даты заказов совпадут, тогда высший ранг (с меньшим по модулю числом) должен получить заказ с большей суммой чека.

# %% [markdown]
# ![image.png](attachment:75b4cff6-cfef-45ed-87b8-24bfa1f5ad41.png)

# %% [markdown]
# #### 7.9

# %% [markdown]
# Для каждого клиента в таблице orders получите дату его предыдущего и последующего заказа (в двух разных столбцах).

# %% [markdown]
# ![image.png](attachment:ae48a3ff-8de7-4f36-a1bc-aca8cadec45f.png)

# %% [markdown]
# ### Общий список задач

# %% [markdown]
# #### 8.1

# %% [markdown]
# Получите список клиентов, которые в 2023 году совершили не менее 15 заказов. Результат отсортируйте по убыванию количества заказов и customer_id.

# %% [markdown]
# ![image.png](attachment:a27bde6d-0f89-4cf1-9501-a0c39507283b.png)

# %% [markdown]
# #### 8.2

# %% [markdown]
# Получите объем продаж и выручку по категориям товаров и городам для магазинов класса "grand". В расчетах учитываются только бренды Xiaomi, Dell, Siemens, Logitech, HP, Sony, Nikon и заказы, оформленные в период с сентября по декабрь 2023 года.
# Выводите только те категории, где было продано не менее 100 единиц товара, сортируя по городу (по возрастанию) и количеству продаж (по убыванию).

# %% [markdown]
# ![image.png](attachment:995f040a-c9a8-42d3-94e7-c2b8b6cbcb2d.png)

# %% [markdown]
# #### 8.3

# %% [markdown]
# Необходимо получить информацию о пяти самых успешных продавцах за период с 1 апреля по 30 июня 2023 года. Успешность определяется количеством уникальных товаров (чем больше проданных уникальных товаров, тем успешнее продавец), которые были проданы каждым продавцом.

# %% [markdown]
# ![image.png](attachment:4322aae1-9fed-49eb-9a40-264032560524.png)

# %% [markdown]
# #### 8.4

# %% [markdown]
# Получите список названий брендов, средняя цена товаров в которых превышает среднюю цену всех остальных товаров. Отсортируйте результат по средней цене по убыванию.

# %% [markdown]
# ![image.png](attachment:8d02e83c-fb95-4a5f-b0ae-527162e30724.png)

# %% [markdown]
# #### 8.5

# %% [markdown]
# Для каждого продавца необходимо рассчитать количество заказов, которые они оформили в месяц своего трудоустройства на работу. Например, если сотрудник устроился на работу в апреле и проработал 2 года, то в результирующем наборе данных должны оказаться все заказы, оформленные за оба апреля. Вывести данные необходимо в порядке убывания количества заказов.

# %% [markdown]
# ![image.png](attachment:9f957c6a-7062-46e1-beb1-6fe3929a86e9.png)

# %% [markdown]
# #### 8.6

# %% [markdown]
# Необходимо определить количество заказов, которые клиенты совершили в течение 90 дней с момента своего первого заказа в каждой категории товаров. При этом необходимо учитывать только тех клиентов и категории, где количество заказов за этот период превышает 2. Результат должен быть отсортирован по убыванию количества заказов.

# %% [markdown]
# ![image.png](attachment:b2bc52b2-99c2-4b8a-a1b3-675ad2676151.png)

# %% [markdown]
# #### 8.7

# %% [markdown]
# Необходимо проанализировать динамику изменений количества товаров, количества заказов и общей суммы скидок по месяцам. Для каждого месяца требуется рассчитать процентное изменение (темп роста или падения) следующих показателей относительно предыдущего месяца:
#
#  - Количество товаров
#  - Количество заказов
#  - Сумма скидок
#
# Результат должен содержать месяц и рассчитанные процентные изменения по каждому показателю. При этом необходимо для самого первого месяца установить значение, равное нулю.

# %% [markdown]
# ![image.png](attachment:2f59d99d-843c-4231-ad72-dd6c2a9a7d91.png)

# %% [markdown]
# #### 8.8

# %% [markdown]
# Для каждой категории товаров необходимо рассчитать средний интервал между заказами клиентов, приобретавших товары из этой категории. В результате для каждой категории должно быть указано ее название и среднее время (в днях), прошедшее между заказами. Результат отсортируйте в порядке возрастания среднего количества дней.

# %% [markdown]
# ![image.png](attachment:de38b695-13f0-441e-b89a-53fa96632cd6.png)

# %% [markdown]
# #### 8.9

# %% [markdown]
# Для каждой категории товаров, проданных в период с 1 июля по 30 сентября 2023 года, необходимо рассчитать среднюю долю, которую эта категория занимает по общей сумме выручки внутри корзины. В результате для каждой категории должно быть указано ее название и средняя доля в процентах, которую она занимает в общей сумме заказов за указанный период. Результат отсортируйте по итоговой доле по убыванию.

# %% [markdown]
# ![image.png](attachment:55c51f0b-8b12-4643-8de0-2dea52cf9b19.png)

# %% [markdown]
# #### 8.10

# %% [markdown]
# Необходимо получить уникальный список клиентов, которые в течение 2023 года приобрели как минимум один товар с UUID '9ed16f97-d414-4162-b956-7fa9deb0f98b', а также хотя бы один из товаров из списка:
#
# '90f023dc-85f3-46d8-910f-b48e69ab9ce7'
# '54f244b4-355f-4930-896e-d5b490d4a405'
# '5453b51c-93fd-452e-94b9-9a93d0b249be'
#
# При этом данные товары не обязательно должны быть в одном заказе.

# %% [markdown]
# ![image.png](attachment:3aabf60c-256e-4d83-af62-a709c74d4c6c.png)

# %% [markdown]
# #### 8.11

# %% [markdown]
# Получите список уникальных клиентов, которые делали покупки во втором квартале 2023 года в Санкт-Петербурге только в магазине по адресу ул. Герцена, д. 11 к. 5/9 и ни в каких других магазинах Санкт-Петербурга.

# %% [markdown]
# ![image.png](attachment:00e28273-67bc-4b73-a0aa-a006fc8db203.png)

# %% [markdown]
# #### 8.12

# %% [markdown]
# Получите расчет удержания клиентов по месяцам (retention rate) аналогичный нашему примеру во второй части курса (раздел с топом интересных сценариев), но с одним важным отличием. В разобранном примере мы рассчитывали удержание по принципу сквозной аналитики. Например, если клиент заказывал в первый месяц, затем не делал покупки во втором месяце (пропустил второй месяц), но затем снова сделал заказ в третий месяц, то такой клиент будет включен в третий месяц. Это означает, что количество клиентов по месяцам может быть как больше, так и меньше относительно предыдущего месяца удержания (кроме первого, месяца когорты). Такой вариант не всегда может подходить к определенным бизнес требованиям. Часто бывает так, что удержание клиентов необходимо рассчитать по принципу воронки, иными словами, в каждый из месяцев удержания мы считаем только тех клиентов, у которых был заказ во все предыдущие месяцы. Если клиент пропустил хотя бы 1 месяц, то он уже не должен быть включен в расчет последующих.
#
# Напиши такой сценарий рассчета удержания по принципу воронки.

# %% [markdown]
# ![image.png](attachment:ddf1858c-e54f-4765-8587-1d5aa2f00cdb.png)

# %% [markdown]
# # Решения задач

# %% [markdown]
# ### Map операции

# %% [markdown]
# #### 1.1

# %% [markdown]
# В таблице order_details есть поле discount_price, оно хранит данные о стоимости на позицию товара в чеке с учетом скидки, при этом в одной позиции может быть несколько товаров, следовательно, столбец discount_price содержит итоговую стоимость всех товаров в позиции. Получите новый вычислямый столбец, котором будет расчитана цена за 1 товар с учетом скидки.

# %%
sql = '''
select
    discount_price,
    quantity,
    discount_price / quantity as price_per_item
from sales.order_details od
'''

# %%
import os
import pandas as pd
import psycopg2
from psycopg2 import Error
import csv
from datetime import (datetime, timedelta)

brands = pd.read_csv('brands.csv', delimiter='|')
categories = pd.read_csv('categories.csv', delimiter='|')
customers = pd.read_csv('customers.csv', delimiter='|')
order_details = pd.read_csv('order_details.csv', delimiter='|')
orders = pd.read_csv('orders.csv', delimiter='|')
products = pd.read_csv('products.csv', delimiter='|')
salesmen = pd.read_csv('salesmen.csv', delimiter='|')
stores = pd.read_csv('stores.csv', delimiter='|')

# %%
order_details['price_per_item'] = order_details['discount_price'] / order_details['quantity']

# %%
order_details[['discount_price', 'quantity', 'price_per_item']].head()
# Out:
#    discount_price  quantity  price_per_item
# 0         25905.6         2         12952.8
# 1         59990.0         1         59990.0
# 2          9980.0         2          4990.0
# 3        399960.0         4         99990.0
# 4       1069990.0         1       1069990.0

# %% [markdown]
# #### 1.2

# %% [markdown]
# Создайте новый вычисляемый столбец в таблице customers, который будет хранить данные о диапазонах возрастов клиентов. Возраст расчитайте относительно даты, в которую вы решаете данную задачу. Используйте следующие рамки для расчета диапазонов:
#
#  - 18 - 24 года
#  - 25 - 34 года
#  - 35 - 44 года
#  - 45 - 54 года
#  - 55 и более

# %%
sql = '''
select
	c.birthday,
	extract(year from age(current_date, c.birthday)),
	case
		when extract(year from age(current_date, c.birthday)) between 18 and 24 then '18 - 24 года'
		when extract(year from age(current_date, c.birthday)) between 25 and 34 then '25 - 34 года'
		when extract(year from age(current_date, c.birthday)) between 35 and 44 then '35 - 44 года'
		when extract(year from age(current_date, c.birthday)) between 45 and 54 then '45 - 54 года'
		else '55 и более'
	end as age_group
from sales.customers c
'''

# %%
# pandas
def age_group(age):
    if 18 <= age <= 24:
        return '18 - 24 года'
    elif 25 <= age <= 34:
        return '25 - 34 года'
    elif 35 <= age <= 44:
        return '35 - 44 года'
    elif 45 <= age <= 54:
        return '45 - 54 года'
    else:
        return '55 и более'
        
customers['birthday'] = pd.to_datetime(customers['birthday'])
customers["age"] = customers['birthday'].apply(
    lambda x: pd.Timestamp.today().year - x.year - ((pd.Timestamp.today().month, pd.Timestamp.today().day) < (x.month, x.day))
)
customers["age_group"] = customers['age'].apply(age_group)

# %%
customers[["birthday", "age_group"]].head()
# Out:
#     birthday     age_group
# 0 1988-08-02  35 - 44 года
# 1 1985-06-02  35 - 44 года
# 2 1987-11-06  35 - 44 года
# 3 1999-04-10  25 - 34 года
# 4 1978-05-18  45 - 54 года

# %% [markdown]
# #### 1.3

# %% [markdown]
# В таблице сотрудников магазина salesmen создайте два вычисляемых поля, в одном должно храниться имя сотрудника, в другом - фамилия.

# %%
sql = '''
select
    s.salesman_name,
	split_part(s.salesman_name, ' ', 1) as name,
	split_part(s.salesman_name, ' ', 2) as surname
from sales.salesmen s 
'''

# %%
# pandas
salesmen[['name', 'surname']] = salesmen['salesman_name'].str.split(' ', expand=True)

# %%
salesmen[['salesman_name', 'name', 'surname']].head()
# Out:
#      salesman_name     name    surname
# 0  Марфа Самсонова    Марфа  Самсонова
# 1     Мокей Галкин    Мокей     Галкин
# 2   Серафим Павлов  Серафим     Павлов
# 3    Лариса Носова   Лариса     Носова
# 4  Ратмир Васильев   Ратмир   Васильев

# %% [markdown]
# #### 1.4

# %% [markdown]
# В таблице orders создайте новое поле, хранящее информацию о годе и номере квартала каждого заказа.

# %%
sql = '''
select
	o.order_date,
	concat(date_part('year', o.order_date), '-', date_part('quarter', o.order_date)) as year_quarter
from sales.orders o 
'''

# %%
orders['order_date'] = pd.to_datetime(orders['order_date'])

# Извлекаем год и квартал
orders['year_quarter'] = orders['order_date'].dt.year.astype(str) + '-' + orders['order_date'].dt.quarter.astype(str)

# %%
orders[['order_date', 'year_quarter']].head()
# Out:
#   order_date year_quarter
# 0 2023-09-19       2023-3
# 1 2024-01-28       2024-1
# 2 2023-11-19       2023-4
# 3 2022-05-14       2022-2
# 4 2023-12-23       2023-4

# %% [markdown]
# #### 1.5

# %% [markdown]
# В таблице order_details в новом столбце рассчитайте сумму скидки в процентах на каждую позицию товаров, результат округлите с точность до 1 знака после запятой.

# %%
sql = '''
select
    od.baseprice,
    od.discount_price,
    round((1 - od.discount_price / od.baseprice)::decimal, 1) * 100 AS discount_percentage
from sales.order_details od
'''

# %%
# pandas
order_details['discount_percentage'] = 100 * round((1 - order_details['discount_price'] / order_details['baseprice']), 1)

# %%
order_details[['baseprice', 'discount_price', 'discount_percentage']].head()
# Out:
#    baseprice  discount_price  discount_percentage
# 0      35980         25905.6                 30.0
# 1      59990         59990.0                  0.0
# 2       9980          9980.0                  0.0
# 3     399960        399960.0                  0.0
# 4    1069990       1069990.0                  0.0

# %% [markdown]
# #### 1.6

# %% [markdown]
# Создайте новый вычисляемый столбец в таблице products с классификацией товаров в зависимости от их цены. Использйте следующие диапазоны:
#
# цена до 10 000 (невключительно) - класс "low price"
# цена от 10 000 (включительно) до 100 000 (невключительно) - класс "medium price"
# цена от 100 000 (включительно) и выше - класс "high price"

# %%
sql = '''
select
    p.price
	case
		when p.price < 10000 then 'low price'
		when p.price >= 10000 and p.price < 100000 then 'medium price'
		else 'high price'
	end as classification
from sales.products p 
'''

# %%
# pandas 
def classification(price):
    if price < 10000:
        return 'low price'
    elif 10000 <= price <= 100000:
        return 'medium price'
    else:
        return 'high price'

products['classification'] = products['price'].apply(classification)

# %%
products[['price','classification']].head(5)
# Out:
#     price classification
# 0   89990   medium price
# 1   84990   medium price
# 2   79990   medium price
# 3  179990     high price
# 4  149990     high price

# %% [markdown]
# ### Операции фильтрации

# %% [markdown]
# #### 2.1

# %% [markdown]
# Из таблицы orders получите такие заказы, которые были сделаны в течении 1 квартала 2023 года.

# %%
sql = '''
select 
    o.check_id,
    o.order_cost,
    o.order_date 
from sales.orders o
where o.order_date between '2023-01-01' and '2023-03-31'
'''

# %%
orders['order_date'] = pd.to_datetime(orders['order_date'])

orders[(orders['order_date'] >= '2023-01-01') & (orders['order_date'] <= '2023-03-31')][['check_id', 
                                                                                         'order_cost', 
                                                                                         'order_date']].head()
# Out:
#     check_id  order_cost order_date
# 45  11145956      407860 2023-03-27
# 51  11145964       84960 2023-02-17
# 58  11145972      649910 2023-03-22
# 62  11145977       14990 2023-03-07
# 63  11145978       19990 2023-03-12

# %% [markdown]
# #### 2.2

# %% [markdown]
# Из таблицы products выведите товары, цена которых находится в диапазоне от 50 000 до 100 000.

# %%
sql = '''
select 
    p.title,
    p.price 
from sales.products p 
where p.price between 50000 and 100000
'''

# %%
products[(products['price'] >= 50000) & (products['price'] <= 100000)][['title', 'price']].head()
# Out:
#                     title  price
# 0           iPhone 14 Pro  89990
# 1        Galaxy S22 Ultra  84990
# 2            Xperia 1 III  79990
# 11  Garmin Forerunner 945  54990
# 39         Huawei P50 Pro  74990

# %% [markdown]
# #### 2.3

# %% [markdown]
# Выведите из таблицы stores список магазинов, расположенных в Москве и относящихся к классу "grand".

# %%
sql = '''
select 
    s.store_uuid,
    s.city,
    s."class" 
from sales.stores s 
where s.city = 'Москва'
and s."class" = 'grand' 
'''

# %%
stores[(stores['city'] == 'Москва') & (stores['class'] == 'grand')][['store_uuid', 'city', 'class']]
# Out:
#                               store_uuid    city  class
# 57  28e25f47-c0eb-4c43-bdf4-ae8e8eb2b907  Москва  grand
# 72  5917d93d-f530-4612-864d-85dae6d3697c  Москва  grand
# 83  9ff20ed9-cfbc-49ff-9589-bdf3f75ea679  Москва  grand

# %% [markdown]
# #### 2.4

# %% [markdown]
# Из таблицы order_details выведите все записи по товарам из следующего списка:
#
#  - (1105042d-9197-4bcd-9668-bb5ab2a76221, 2487e34e-728d-4d0b-818b-45f8f111f853, b5355c21-48ad-42e7-9ee6-ebe9085881a3)

# %%
sql = '''
select 
    od.*
from sales.order_details od 
where od.product_uuid in (
    '1105042d-9197-4bcd-9668-bb5ab2a76221', 
    '2487e34e-728d-4d0b-818b-45f8f111f853', 
    'b5355c21-48ad-42e7-9ee6-ebe9085881a3'
)
'''

# %%
order_details[order_details['product_uuid'].isin(['1105042d-9197-4bcd-9668-bb5ab2a76221', 
                        						  '2487e34e-728d-4d0b-818b-45f8f111f853', 
                        						  'b5355c21-48ad-42e7-9ee6-ebe9085881a3'])].head()
# Out:
#      line_id                          product_uuid  baseprice  discount_price  \
# 3        115  2487e34e-728d-4d0b-818b-45f8f111f853     399960        399960.0
# 9        169  1105042d-9197-4bcd-9668-bb5ab2a76221      74970         66723.3
# 12       196  2487e34e-728d-4d0b-818b-45f8f111f853     299970        299970.0
# 28       340  b5355c21-48ad-42e7-9ee6-ebe9085881a3      14990         14990.0
# 235     2203  1105042d-9197-4bcd-9668-bb5ab2a76221      99960         99960.0
#
#      quantity  check_id
# 3           4  11398196
# 9           3  11181013
# 12          3  11240060
# 28          1  11216784
# 235         4  11896508

# %% [markdown]
# #### 2.5

# %% [markdown]
# Из таблицы customers выведите всех клиентов, имя которых начинается на букву А и имеет 5 и более букв в своем составе.

# %%
sql = '''
select 
    c.customer_id,
    c.customer_name 
from sales.customers c 
where split_part(c.customer_name, ' ', 1) like 'А____%'
'''

# %%
customers[customers['customer_name'].str.split().str[0].\
                    apply(lambda x: len(x) >= 5 and x.startswith('А'))][['customer_id',
                                                                         'customer_name']].head()
# Out:
#     customer_id      customer_name
# 15          467    Алевтина Жукова
# 33          629     Аристарх Панов
# 40          692      Аникита Лапин
# 50          782  Антонина Матвеева
# 76         1016  Анатолий Мамонтов

# %% [markdown]
# #### 2.6

# %% [markdown]
# Выведите всех клиентов, фамилии которых заканчиваются на буквы "в" или "н", при этом email таких клиентов должен заканчиваться на "@gmail.com" (таблица customers).

# %%
sql = '''
select 
    c.customer_id,
    c.customer_name,
    c.email 
from sales.customers c 
where split_part(c.customer_name, ' ', 2) similar to '%[вн]' 
and c.email like '%@gmail.com'
'''

# %%
customers[
    customers['customer_name'].str.split().str[1].str.endswith(('в', 'н')) &
    customers['email'].str.endswith('@gmail.com')
][['customer_id', 'customer_name', 'email']].head()
# Out:
#     customer_id    customer_name                      email
# 3           359   Ладимир Маслов  anastasija_1977@gmail.com
# 34          638    Будимир Зыков    venedikt_2010@gmail.com
# 40          692    Аникита Лапин          arefi61@gmail.com
# 44          728  Прохор Воробьев   nikolaagafonov@gmail.com
# 45          737  Изяслав Русаков    kuzminazhanna@gmail.com

# %% [markdown]
# #### 2.7

# %% [markdown]
# Получите список магазинов, площадь которых составляет не более 300 кв.м, при этом находящихся в одном из городов (Москва, Ульяновск, Волгоград), или же таких магазинов, класс которых является grand или mini, при этом расположенных на какой-либо аллее (в начале адреса присутствует сокращение алл.) (таблица stores).

# %%
sql = '''
select 
    s.address,
    s.city,
    s.area,
    s."class" 
from sales.stores s 
where 1=1
and (s.area <= 300 and s.city in ('Москва', 'Ульяновск', 'Волгоград'))
or (s."class" in ('grand', 'mini') and s.address like 'алл.%')
'''

# %%
stores[
    ((stores['area'] <= 300) & (stores['city'].isin(['Москва', 'Ульяновск', 'Волгоград']))) |
    ((stores['class'].isin(['grand', 'mini'])) & (stores['address'].str.startswith('алл.')))
][['address', 'city', 'area', 'class']].head()
# Out:
#                           address       city  area   class
# 7    наб. Семашко, д. 2/7 стр. 15     Москва   262  medium
# 12  наб. Прохладная, д. 1 стр. 70     Москва    98    mini
# 27      бул. Угловой, д. 5 стр. 3  Волгоград   107    mini
# 36     алл. Почтовая, д. 2 к. 218       Омск   508   grand
# 41       алл. Красноярская, д. 85  Хабаровск   393   grand

# %% [markdown]
# #### 2.8

# %% [markdown]
# Из таблицы orders получите такие заказы, количество товаров которых находится в рамках от 2 до 5 штук, сумма чека с учетом скидки не превышает 100 000, также заказ должен быть сделан в 2022 году.

# %%
sql = '''
select 
    o.check_id,
    o.count_goods,
    o.order_discount_cost,
    o.order_date 
from sales.orders o
where 1=1
and o.count_goods between 2 and 5
and o.order_discount_cost <= 100000
and o.order_date between '2022-01-01' and '2022-12-31'
'''

# %%
orders['order_date'] = pd.to_datetime(orders['order_date'])

orders[
    (orders['count_goods'].between(2, 5)) &
    (orders['order_discount_cost'] <= 100000) &
    (orders['order_date'].between('2022-01-01', '2022-12-31'))
][['check_id', 'count_goods', 'order_discount_cost', 'order_date']].head()
# Out:
#      check_id  count_goods  order_discount_cost order_date
# 26   11145930            3              89970.0 2022-06-13
# 71   11145988            4              99960.0 2022-08-25
# 100  11146029            3              14970.0 2022-06-04
# 105  11146034            2              11980.0 2022-05-24
# 115  11146044            2              29080.6 2022-11-13

# %% [markdown]
# #### 2.9

# %% [markdown]
# Из таблицы order_details выведите данные по чекам, в которых каждая позиция содержит не менее 2 товаров, базовая стоимость позиции товара находится в пределах от 100 до 300 тысяч. Еще одним условием является то, что в позициях не должно быть товаров из данного списка:
# (
# bd7e5101-71be-4935-b3e5-324636baecd6,
# 9088aa9a-3248-4f1a-ab3d-5527e4cd6521,
# 6febba3f-5ba3-428e-904f-048d9fd76897,
# 4864ff98-69e3-4fa5-95c9-a5d35c4cdaa5,
# 96e9a531-230e-4237-8011-da09df534aaa,
# a720c029-0703-4120-9559-99243fe5f2b1,
# fcec9f7c-1c9e-4669-87ce-a207713349e7
# )

# %%
sql = '''
select 
    od.*
from sales.order_details od 
where 1=1
and od.quantity > 1
and od.baseprice between 100000 and 300000
and od.product_uuid not in (
    'bd7e5101-71be-4935-b3e5-324636baecd6', 
    '9088aa9a-3248-4f1a-ab3d-5527e4cd6521', 
    '6febba3f-5ba3-428e-904f-048d9fd76897', 
    '4864ff98-69e3-4fa5-95c9-a5d35c4cdaa5', 
    '96e9a531-230e-4237-8011-da09df534aaa', 
    'a720c029-0703-4120-9559-99243fe5f2b1', 
    'fcec9f7c-1c9e-4669-87ce-a207713349e7'
)
'''

# %%
excluded_products = [
    'bd7e5101-71be-4935-b3e5-324636baecd6',
    '9088aa9a-3248-4f1a-ab3d-5527e4cd6521',
    '6febba3f-5ba3-428e-904f-048d9fd76897',
    '4864ff98-69e3-4fa5-95c9-a5d35c4cdaa5',
    '96e9a531-230e-4237-8011-da09df534aaa',
    'a720c029-0703-4120-9559-99243fe5f2b1',
    'fcec9f7c-1c9e-4669-87ce-a207713349e7'
]

order_details[
    (order_details['quantity'] > 1) &
    (order_details['baseprice'].between(100000, 300000)) &
    (~order_details['product_uuid'].isin(excluded_products))
].head()
# Out:
#     line_id                          product_uuid  baseprice  discount_price  \
# 8       160  8047f706-4d38-4008-ae18-21b5964bb59d     119960        119960.0
# 10      178  e1cb209c-b210-451f-9852-cae166d5b070     299980        299980.0
# 12      196  2487e34e-728d-4d0b-818b-45f8f111f853     299970        299970.0
# 16      232  2a5df599-68d8-411e-b660-095743c2bf15     259960        246962.0
# 17      241  4faa151c-3186-4bc3-bedc-4a4762182abb     139960        139960.0
#
#     quantity  check_id
# 8          4  11679199
# 10         2  11452004
# 12         3  11240060
# 16         4  11623116
# 17         4  11714228

# %% [markdown]
# ### Операции группировки, транспонирования

# %% [markdown]
# #### 3.1

# %% [markdown]
# Посчитайте общее количество проданных товаров за все время, общую сумму выручки с учетом и без учета скидки и общее количество уникальных заказов (таблица orders).

# %%
sql = '''
select
	sum(o.count_goods) as cnt_all_goods,
	sum(o.order_cost) as revenue,
	sum(o.order_discount_cost) as revenue_with_discount,
	count(o.check_id) as unique_orders
from sales.orders o
'''

# %%
result = orders.agg({
    "count_goods": "sum",
    "order_cost": "sum",
    "order_discount_cost": "sum",
    "check_id": "count"
}).rename({
    "count_goods": "cnt_all_goods",
    "order_cost": "revenue",
    "order_discount_cost": "revenue_with_discount",
    "check_id": "unique_orders"
})
result
# Out:
# cnt_all_goods            3.017106e+06
# revenue                  1.990107e+11
# revenue_with_discount    1.870469e+11
# unique_orders            6.146910e+05
# dtype: float64

# %% [markdown]
# #### 3.2

# %% [markdown]
# Посчитайте количество уникальных клиентов магазина (таблица customers или таблица orders).

# %%
sql = '''
select
	count(distinct o.customer_id) as unique_users
from sales.orders o
'''

# %%
orders["customer_id"].nunique()
# Out:
# 54260

# %% [markdown]
# #### 3.3

# %% [markdown]
# Рассчитайте продажи (суммарное количество проданных товаров), сумму выручки с учетом скидки, максимальное и минимальное количество товаров в чеке и среднюю сумму чека без учета скидки с группировкой по датам заказов (таблица orders).

# %%
sql = '''
select
	o.order_date,
	sum(o.count_goods) as cnt_goods,
	sum(o.order_discount_cost) as revenue_with_discount,
	max(o.count_goods) as max_goods,
	min(o.count_goods) as min_goods,
	avg(o.order_cost) as avg_check
from sales.orders o
group by o.order_date
'''

# %%
orders.groupby("order_date").agg(
    cnt_goods=("count_goods", "sum"),
    revenue_with_discount=("order_discount_cost", "sum"),
    max_goods=("count_goods", "max"),
    min_goods=("count_goods", "min"),
    avg_check=("order_cost", "mean")
).reset_index().head()
# Out:
#    order_date  cnt_goods  revenue_with_discount  max_goods  min_goods  \
# 0  2022-05-01       3593            247105137.2         16          1
# 1  2022-05-02       4068            269271673.7         18          1
# 2  2022-05-03       4197            256699199.9         18          1
# 3  2022-05-04       3862            232400333.1         20          1
# 4  2022-05-05       3889            258653979.6         19          1
#
#        avg_check
# 0  347078.880105
# 1  343887.001195
# 2  325802.810615
# 3  324796.294350
# 4  340245.523691

# %% [markdown]
# #### 3.4

# %% [markdown]
# Рассчитайте количество сотрудников в каждой должности (таблица salesmen).

# %%
sql = '''
select
	s.fn,
	count(s.salesman_id) as cnt_salesmen
from salesmen s
group by s.fn
'''

# %%
salesmen.groupby("job").agg(cnt_salesmen=("salesman_id", "count")).reset_index()
# Out:
#                                job  cnt_salesmen
# 0                           Кассир           308
# 1             Продавец-консультант           227
# 2                 Сотрудник склада           146
# 3  Специалист по кредитным заявкам           131
# 4                   Старший кассир            69

# %% [markdown]
# #### 3.5

# %% [markdown]
# Посчитайте сумму выручки и продажи с группировкой по датам и идентификаторам магазинов (таблица orders).

# %%
sql = '''
select
	o.order_date, 
	o.store_uuid,
	sum(o.order_discount_cost) as revenue,
	sum(o.count_goods) as sales
from orders o
group by o.order_date, o.store_uuid
'''

# %%
orders.groupby(["order_date", "store_uuid"]).agg(
    revenue=("order_discount_cost", "sum"),
    sales=("count_goods", "sum")
).reset_index().head()
# Out:
#    order_date                            store_uuid     revenue  sales
# 0  2022-05-01  029c7595-9110-4b06-b941-e1c3db2ecf91   2714938.6     70
# 1  2022-05-01  0af78faf-1b7f-4a4d-b852-3f3478a13423  10317712.0     30
# 2  2022-05-01  0da2586b-fce9-4f29-9757-6a0393957c7b   1952651.7     26
# 3  2022-05-01  1075decc-8958-47ae-b0db-b9db6697e91a    645088.1     20
# 4  2022-05-01  17caff53-0a89-4a59-abf2-4ed5764b9ec3   4341061.4     41

# %% [markdown]
# #### 3.6

# %% [markdown]
# Выведите количество товаров по каждому бренду и категории (можно использовать идентификаторы brand_id и category_id) (таблица products).

# %%
sql = '''
select
	p.brand_id, 
	p.category_id,
	count(p.product_uuid) as cnt_products
from products p
group by p.brand_id, p.category_id
'''

# %%
products.groupby(["brand_id", "category_id"]).agg(
    cnt_products=("product_uuid", "count")
).reset_index().head()
# Out:
#    brand_id  category_id  cnt_products
# 0     10448          444             4
# 1     10879          777             5
# 2     11367         1221             5
# 3     12281          111             3
# 4     12573         1221             3

# %% [markdown]
# #### 3.7

# %% [markdown]
# Какое количество заказов сделал каждый клиент за все время? Получите также максимальную и минимальную сумму чека по каждому клиенту за всю историю заказов (таблица orders).

# %%
sql = '''
select
	o.customer_id,
	count(check_id) as cnt_orders,
	max(o.order_discount_cost) as max_check,
	min(o.order_discount_cost) as min_check
from orders o
group by o.customer_id
'''

# %%
orders.groupby("customer_id").agg(
    cnt_orders=("check_id", "count"),
    max_check=("order_discount_cost", "max"),
    min_check=("order_discount_cost", "min")
).reset_index().head()
# Out:
#    customer_id  cnt_orders  max_check  min_check
# 0          332          16   471520.8     7160.0
# 1          341          10  2381144.8     2490.0
# 2          350          11  1022981.4     1690.0
# 3          359          13  4464024.4    19990.0
# 4          368          14  3299990.0    27980.0

# %% [markdown]
# #### 3.8

# %% [markdown]
# Скольких уникальных клиентов обслужил каждый сотрудник магазина? (таблица orders).

# %%
sql = '''
select
	o.salesman_id,
	count(distinct o.customer_id) as cnt_users
from orders o
group by o.salesman_id
'''

# %%
orders.groupby("salesman_id").agg(
    cnt_users=("customer_id", pd.Series.nunique)
).reset_index().head()
# Out:
#    salesman_id  cnt_users
# 0       137052        656
# 1       137055        663
# 2       137058        669
# 3       137061        740
# 4       137064        693

# %% [markdown]
# #### 3.9

# %% [markdown]
# Сколько было продано в штуках каждого товара за всю историю? (таблица order_details).

# %%
sql = '''
select
	od.product_uuid,
	sum(od.quantity) as cnt_goods
from order_details od
group by od.product_uuid
'''

# %%
order_details.groupby("product_uuid").agg(
    cnt_goods=("quantity", "sum")
).reset_index().head()
# Out:
#                            product_uuid  cnt_goods
# 0  0047f791-ba15-4db2-8563-5a774d25d13e       2713
# 1  00635777-4c27-4fb2-bcd5-6a0fed0e73b7       2542
# 2  007c8dcd-8129-481e-8860-bf8a31d1a361       2862
# 3  008b640e-9cc3-4014-af45-3509fc8aa9a7       2505
# 4  01499186-7b45-4b43-be2d-4438106b85e7       2805

# %% [markdown]
# ### Операции join

# %% [markdown]
# #### 4.1

# %% [markdown]
# Проведите операцию внутреннего соединения между таблицами products, brands и categories.

# %%
sql = '''
select
	*
from products p
inner join brands b on p.brand_id = b.brand_id
inner join categories c on p.category_id = c.category_id
'''

# %%
products.merge(brands, on="brand_id").merge(categories, on="category_id").head()
# Out:
#                            product_uuid              title   price  \
# 0  d47d5137-561f-4909-8ae1-cb4ee4843fd4      iPhone 14 Pro   89990
# 1  d1c26233-17ab-44c1-a901-47b5e86ca508   Galaxy S22 Ultra   84990
# 2  21d527e7-0edc-4324-ba75-83573f4e3eee       Xperia 1 III   79990
# 3  db60b4f4-f14f-4145-ab76-e2fed4c18461         LG OLED CX  179990
# 4  db79cc72-442b-4241-85b5-8a3823a9253e  Samsung QLED Q90T  149990
#
#    category_id  brand_id brand_name category_name
# 0          111     51244      Apple     Смартфоны
# 1          111     21909    Samsung     Смартфоны
# 2          111     69450       Sony     Смартфоны
# 3          222     59056         LG            ТВ
# 4          222     21909    Samsung            ТВ

# %% [markdown]
# #### 4.2

# %% [markdown]
# Расширьте атрибутный состав таблицы orders так, чтобы иметь доступ к адресам и классам магазинов.

# %%
sql = '''
select
	o.check_id,
    s.address,
	s."class"
from orders o
inner join stores s on o.store_uuid = s.store_uuid
'''

# %%
orders.merge(stores, on="store_uuid")[['check_id' ,'address', 'class']].head()
# Out:
#    check_id                       address   class
# 0  11145900    ш. Карла Либкнехта, д. 426   grand
# 1  11145901  наб. Ангарская, д. 12 стр. 1    mini
# 2  11145902              алл. ДОС, д. 9/6   grand
# 3  11145903           ш. Болотное, д. 6/9   grand
# 4  11145904       пер. Терешковой, д. 952  medium

# %% [markdown]
# #### 4.3

# %% [markdown]
# Получите только такие заказы для каждого клиента, которые были сделаны в его день рождения. Также можете реализовать чуть более сложный вариант данной задачи, а именно, выведите такие заказы для каждого клиента, которые были сделаны в период за 5 дней до и за 5 дней после дня рождения клиента.

# %%
sql = '''
select
	o.customer_id,
	c.birthday, 
    o.order_date,
	o.check_id
from orders o
inner join customers c on o.customer_id = c.customer_id
--and to_char(o.order_date, 'MM-DD') = to_char(c.birthday, 'MM-DD')
and to_char(o.order_date, 'MM-DD') between to_char(c.birthday - interval '5 days', 'MM-DD') and to_char(c.birthday + interval '5 days', 'MM-DD') -- Более сложный вариант
'''

# %%
# Простой вариант
orders['order_date'] = pd.to_datetime(orders['order_date'])
customers["birthday"] = pd.to_datetime(customers["birthday"])

# Преобразуем даты к формату без учета года
orders["order_month_day"] = orders["order_date"].dt.strftime("%m-%d")
customers["birthday_month_day"] = customers["birthday"].dt.strftime("%m-%d")

orders.merge(customers, on="customer_id").query(
    "order_month_day == birthday_month_day"
)[["customer_id", "birthday", "order_date", "check_id"]].head()
# Out:
#       customer_id   birthday order_date  check_id
# 211        414197 1983-09-26 2023-09-26  11146164
# 221         76940 1983-07-19 2023-07-19  11146175
# 447         10826 1983-03-05 2024-03-05  11146473
# 1447        67913 1979-02-28 2023-02-28  11147736
# 2476       373922 2004-02-05 2024-02-05  11149045

# %%
# Сложный вариант
orders['order_date'] = pd.to_datetime(orders['order_date'])
customers["birthday"] = pd.to_datetime(customers["birthday"])

# Создаем минимальную и максимальную дату ±5 дней от дня рождения
customers["birthday_min"] = customers["birthday"].apply(
    lambda x: (x - pd.DateOffset(days=5)).strftime("%m-%d")
)
customers["birthday_max"] = customers["birthday"].apply(
    lambda x: (x + pd.DateOffset(days=5)).strftime("%m-%d")
)

# Преобразуем дату заказа к формату без учета года
orders["order_md"] = orders["order_date"].dt.strftime("%m-%d")

# Объединяем таблицы и фильтруем по диапазону
result = orders.merge(customers, on="customer_id")
result[(result["order_md"] >= result["birthday_min"]) & 
       (result["order_md"] <= result["birthday_max"])][['customer_id', 'birthday', 'order_date', 'check_id']].head()
# Out:
#      customer_id   birthday order_date  check_id
# 11        375848 1986-05-16 2022-05-12  11145912
# 52        461465 2004-02-29 2024-03-01  11145965
# 119       368315 1989-06-27 2023-07-02  11146049
# 157       107756 1992-07-05 2022-07-03  11146097
# 180       459350 1999-01-15 2024-01-13  11146127

# %% [markdown]
# #### 4.4

# %% [markdown]
# Получите только такие заказы, которые были сделаны в день устройства сотрудника на работу.

# %%
sql = '''

select
	o.salesman_id,
	s.date_of_employment, 
    o.order_date,
	o.check_id
from sales.orders o
inner join sales.salesmen s on o.salesman_id = s.salesman_id 
					   and to_char(o.order_date, 'MM-DD') = to_char(s.date_of_employment, 'MM-DD')

'''

# %%
# Простой вариант
orders['order_date'] = pd.to_datetime(orders['order_date'])
salesmen["date_of_employment"] = pd.to_datetime(salesmen["date_of_employment"])

# Преобразуем даты к формату без учета года
orders["order_month_day"] = orders["order_date"].dt.strftime("%m-%d")
salesmen["date_of_employment_month_day"] = salesmen["date_of_employment"].dt.strftime("%m-%d")

orders.merge(salesmen, on = "salesman_id").query(
    "order_month_day == date_of_employment_month_day"
)[["salesman_id", "date_of_employment", "order_date", "check_id"]].head()
# Out:
#       salesman_id date_of_employment order_date  check_id
# 223        138537         2022-03-06 2023-03-06  11146178
# 436        137838         2018-11-04 2022-11-04  11146459
# 1025       138513         2020-03-08 2024-03-08  11147215
# 1238       137322         2019-09-29 2022-09-29  11147477
# 1496       138273         2018-06-18 2022-06-18  11147797

# %% [markdown]
# #### 4.5

# %% [markdown]
# Проведите операцию внутреннего соединения для всех таблиц нашей тренировочной модели данных.

# %%
sql = '''

select 
		*
from sales.order_details od 
inner join sales.orders o on o.check_id = od.check_id 
inner join sales.stores s on s.store_uuid = o.store_uuid 
inner join sales.salesmen s2 on s2.salesman_id = o.salesman_id 
inner join sales.customers c on c.customer_id = o.customer_id 
inner join sales.products p on p.product_uuid = od.product_uuid 
inner join sales.categories c2 on c2.category_id = p.category_id 
inner join sales.brands b on b.brand_id = p.brand_id 

'''

# %%
order_details.merge(orders, on = 'check_id', how = 'inner').\
              merge(stores, on = 'store_uuid', how = 'inner').\
              merge(salesmen, on = 'salesman_id', how = 'inner').\
              merge(customers, on = 'customer_id', how = 'inner').\
              merge(products, on = 'product_uuid', how = 'inner').\
              merge(categories, on = 'category_id', how = 'inner').\
              merge(brands, on = 'brand_id', how = 'inner').head()
# Out:
#    line_id                          product_uuid  baseprice  discount_price  \
# 0       88  4bd0692a-98f6-44cc-80a3-a821a10a87cd      35980         25905.6
# 1       97  77221978-1720-4a63-ab7e-eaa263e43725      59990         59990.0
# 2      106  69c3dc2c-96c7-4bdf-8906-5ee3d8e775cd       9980          9980.0
# 3      115  2487e34e-728d-4d0b-818b-45f8f111f853     399960        399960.0
# 4      124  098d196e-1b5d-48ab-b8eb-c61910acec16    1069990       1069990.0
#
#    quantity  check_id  order_cost  order_discount_cost  count_goods  \
# 0         2  11615302      104950              82461.0            5
# 1         1  11382863       79970              79970.0            3
# 2         2  11234368       24950              24950.0            5
# 3         4  11398196      479920             467926.0            8
# 4         1  11528345     1391630            1381249.2            7
#
#   order_date  ...       customer_name    birthday              mobile  \
# ...

# %% [markdown]
# #### 4.6

# %% [markdown]
# Получите список клиентов, у которых день рождения (день и месяц) совпадает с днем и месяцем устройства на работу хотя бы 1 сотрудника из штата магазинов.

# %%
sql = '''

select
	s.salesman_name,
	s.date_of_employment, 
    c.customer_name,
    c.birthday 
from sales.customers c 
inner join sales.salesmen s on to_char(c.birthday, 'MM-DD') = to_char(s.date_of_employment, 'MM-DD')

'''

# %%
customers['birthday'] = pd.to_datetime(customers['birthday'])
salesmen["date_of_employment"] = pd.to_datetime(salesmen["date_of_employment"])

# Преобразуем даты к формату без учета года
customers["month_day"] = customers['birthday'].dt.strftime("%m-%d")
salesmen["month_day"] = salesmen["date_of_employment"].dt.strftime("%m-%d")

customers.merge(salesmen, on = "month_day")[["salesman_name", "date_of_employment", "customer_name", "birthday"]].head()
# Out:
#        salesman_name date_of_employment       customer_name   birthday
# 0    Нонна Ларионова         2021-08-02  Селиверст Самойлов 1988-08-02
# 1    Раиса Федосеева         2018-06-02     Кира Афанасьева 1985-06-02
# 2  Дементий Щербаков         2018-06-02     Кира Афанасьева 1985-06-02
# 3    Сергей Медведев         2020-06-02     Кира Афанасьева 1985-06-02
# 4    Регина Елисеева         2019-06-02     Кира Афанасьева 1985-06-02

# %% [markdown]
# ### Операции конкатенации

# %% [markdown]
# #### 5.1

# %% [markdown]
# Используя операцию со множествами, проверьте, есть ли такие клиенты, которые ни разу не делали никаких заказов за всю историю.

# %%
sql = '''

select 
	c.customer_id
from customers c 
except
select 
	distinct o.customer_id
from orders o

'''

# %%
customers[~customers['customer_id'].isin(orders['customer_id'].unique())]['customer_id']
# Out:
# Series([], Name: customer_id, dtype: int64)

# %% [markdown]
# #### 5.2

# %% [markdown]
# С помощью операции со множествами получите список имен и фамилий клиентов и сотрудников, исключив при этом дублирующиеся записи.

# %%
sql = '''

select 
	c.customer_name
from customers c 
union
select
	s.salesman_name
from salesmen s

'''

# %%
pd.concat([customers['customer_name'], salesmen['salesman_name']]).drop_duplicates().reset_index(drop=True).head()
# Out:
# 0    Селиверст Самойлов
# 1       Кира Афанасьева
# 2      Семен Комиссаров
# 3        Ладимир Маслов
# 4       Нонна Субботина
# dtype: object

# %% [markdown]
# #### 5.3

# %% [markdown]
# Через операцию со множествами получите список имен и фамилий, которые совпадают у клиентов и сотрудников сети.

# %%
sql = '''

select 
	c.customer_name
from customers c 
intersect
select
	s.salesman_name
from salesmen s

'''

# %%
pd.Series(list(set(customers['customer_name']).intersection(set(salesmen['salesman_name']))))
# Out:
# 0          Клавдия Павлова
# 1          Наталья Орехова
# 2      Раиса Константинова
# 3           Куприян Пестов
# 4             Ия Субботина
#               ...
# 450           Мир Максимов
# 451       Елизар Харитонов
# 452           Фирс Казаков
# 453       Фаина Харитонова
# 454       Лариса Гаврилова
# Length: 455, dtype: object

# %% [markdown]
# ### Операции сортировки

# %% [markdown]
# #### 6.1

# %% [markdown]
# Получите таблицу со списком клиентов, отсортированную по дате рождения по возрастанию

# %%
sql = '''

select
	c.customer_name,
	c.birthday
from customers c 
order by c.birthday

'''

# %%
customers['birthday'] = pd.to_datetime(customers['birthday'])
customers.sort_values(by='birthday')[['customer_name', 'birthday']].head()
# Out:
#           customer_name   birthday
# 2381      Лонгин Беляев 1975-01-01
# 41938  Леонтий Прохоров 1975-01-01
# 29290     Елизар Уваров 1975-01-01
# 13578      Ия Мамонтова 1975-01-01
# 37503  Антонина Жданова 1975-01-02

# %% [markdown]
# #### 6.2

# %% [markdown]
# Получите таблицу со списком сотрудников, отсортировав данные по дате устройства на работу по возрастанию и по имени и фамилии по убыванию.

# %%
sql = '''

select
	s.salesman_name,
	s.date_of_employment 
from salesmen s  
order by s.date_of_employment, s.salesman_name desc

'''

# %%
salesmen['date_of_employment'] = pd.to_datetime(salesmen['date_of_employment'])
salesmen.sort_values(by=['date_of_employment', 'salesman_name'], ascending=[True, False])[['salesman_name', 'date_of_employment']].head()
# Out:
#           salesman_name date_of_employment
# 263  Элеонора Кириллова         2018-01-01
# 857      Сократ Лазарев         2018-01-01
# 860       Эмиль Кулаков         2018-01-02
# 831    Гаврила Селезнев         2018-01-04
# 366  Денис Красильников         2018-01-05

# %% [markdown]
# #### 6.3

# %% [markdown]
# Выведите данные из таблицы products, отсортировав их по цене и названию товара по убыванию.

# %%
sql = '''

select
	*
from products p  
order by p.price desc, p.title desc

'''

# %%
products.sort_values(by=['price', 'title'], ascending=[False, False]).head()
# Out:
#                              product_uuid              title    price  \
# 902  97a0d586-d806-4bf3-9d7c-8d65f9fc0f25     Sony KD-77A88J  3299990
# 757  6e8f5fd4-04d0-4d26-998f-236e4bf41981     Sony KD-100Z9J  2999990
# 554  41c87ea3-9060-4814-abeb-8b454b2dc42a        Pentax 645Z  2499990
# 901  307c8f45-b089-470c-9212-a30018b90ebc  Samsung QE85QN85A  2199990
# 841  aa9b3666-38df-47cd-9939-e15f5cb005ae          Leica M11  1899990
#
#      category_id  brand_id
# 902          222     69450
# 757          222     69450
# 554          999     76088
# 901          222     21909
# 841          999     98130

# %% [markdown]
# ### Оконные функции, накопительный итог

# %% [markdown]
# #### 7.1

# %% [markdown]
# В таблице products создайте новый столбец, показывающий в каждой строке общее количество уникальных товаров, продающихся в сети магазинов.

# %%
sql = '''

select 
		p.product_uuid,
		p.title,
		count(*) over() as cnt_products
from sales.products p 

'''

# %%
# Добавляем новый столбец с этим значением
products['cnt_products'] = len(products)

products[['product_uuid', 'title', 'cnt_products']].head()
# Out:
#                            product_uuid              title  cnt_products
# 0  d47d5137-561f-4909-8ae1-cb4ee4843fd4      iPhone 14 Pro          1153
# 1  d1c26233-17ab-44c1-a901-47b5e86ca508   Galaxy S22 Ultra          1153
# 2  21d527e7-0edc-4324-ba75-83573f4e3eee       Xperia 1 III          1153
# 3  db60b4f4-f14f-4145-ab76-e2fed4c18461         LG OLED CX          1153
# 4  db79cc72-442b-4241-85b5-8a3823a9253e  Samsung QLED Q90T          1153

# %% [markdown]
# #### 7.2

# %% [markdown]
# В таблице products напротив каждого бренда проставьте среднюю цену составляющих его товаров, гранулярность таблицы products не должна измениться.

# %%
sql = '''

select 
		p.title,
		p.brand_id,
		avg(p.price) over(partition by p.brand_id) as avg_price_by_brands
from sales.products p

'''

# %%
products = pd.read_csv("products.csv", sep = '|')

products['avg_price_by_brands'] = products.groupby('brand_id')['price'].transform('mean')

# Вывод результата
products[['title', 'brand_id', 'avg_price_by_brands']].sort_values(by = 'brand_id').head()
# Out:
#                                           title  brand_id  avg_price_by_brands
# 639                         Spigen Ultra Hybrid     10448               1690.0
# 587                           Spigen Liquid Air     10448               1690.0
# 516                          Spigen Tough Armor     10448               1690.0
# 763                           Spigen Neo Hybrid     10448               1690.0
# 1097  EVGA SuperNOVA 1000 G5 1000W 80+ Gold PSU     10879              13390.0

# %% [markdown]
# #### 7.3

# %% [markdown]
# Теперь добавьте разбивку также по категории, иными словами, рассчитайте среднюю цену товаров, входящих в каждый бренд каждой категории. Гранулярность таблицы products не должна измениться.

# %%
sql = '''

select 
		p.title,
		p.brand_id,
		p.category_id,
		avg(p.price) over(partition by p.brand_id, p.category_id) as avg_price_by_brands_categories
from sales.products p

'''

# %%
products = pd.read_csv("products.csv", sep = '|')

products['avg_price_by_brands_categories'] = products.groupby(['brand_id', 'category_id'])['price'].transform('mean')

# Вывод результата
products[['title', 
          'brand_id', 
          'category_id', 
          'avg_price_by_brands_categories']].sort_values(by = ['brand_id', 'category_id']).head()
# Out:
#                                         title  brand_id  category_id  \
# 516                        Spigen Tough Armor     10448          444
# 587                         Spigen Liquid Air     10448          444
# 639                       Spigen Ultra Hybrid     10448          444
# 763                         Spigen Neo Hybrid     10448          444
# 1055  EVGA SuperNOVA 750 G5 750W 80+ Gold PSU     10879          777
#
#       avg_price_by_brands_categories
# 516                           1690.0
# 587                           1690.0
# 639                           1690.0
# 763                           1690.0
# 1055                         13390.0

# %% [markdown]
# #### 7.4

# %% [markdown]
# В таблице orders напротив каждого клиента получите общее количество его заказов за всю историю, при этом гранулярность таблицы не должна измениться.

# %%
sql = '''

select 
		o.check_id,
		o.customer_id,
		count(o.check_id) over(partition by o.customer_id) as cnt_orders_by_client
from sales.orders o

'''

# %%
orders = pd.read_csv("orders.csv", sep = '|')  

orders['cnt_orders_by_client'] = orders.groupby('customer_id')['check_id'].transform('count')

# Вывод результата
orders[['check_id', 'customer_id', 'cnt_orders_by_client']].sort_values(by = 'customer_id').head()
# Out:
#         check_id  customer_id  cnt_orders_by_client
# 40087   11196445          332                    16
# 120831  11297936          332                    16
# 449065  11710130          332                    16
# 112342  11287257          332                    16
# 212919  11413718          332                    16

# %% [markdown]
# #### 7.5

# %% [markdown]
# По каждому сотруднику магазинов в таблице orders рассчитайте максимальную сумму чека с учетом скидки среди когда-либо оформленных заказов, гранулярность таблицы orders не должна измениться.

# %%
sql = '''

select 
		o.check_id,
		o.salesman_id,
		max(o.order_discount_cost) over(partition by o.salesman_id) as max_check_by_salesman
from sales.orders o 

'''

# %%
orders = pd.read_csv("orders.csv", sep = '|')  

orders['max_check_by_salesman'] = orders.groupby('salesman_id')['order_discount_cost'].transform('max')

# Вывод результата
orders[['check_id', 'salesman_id', 'max_check_by_salesman']].sort_values(by = 'salesman_id').head()
# Out:
#         check_id  salesman_id  max_check_by_salesman
# 389212  11635022       137052              5299900.0
# 531756  11813951       137052              5299900.0
# 323893  11552933       137052              5299900.0
# 140352  11322450       137052              5299900.0
# 126666  11305288       137052              5299900.0

# %% [markdown]
# #### 7.6

# %% [markdown]
# По каждому клиенту в таблице orders расчитайте накопительную сумму чеков по его заказам (с учетом скидки), отсортировав даты покупок по возрастанию.

# %%
sql = '''

select 
		o.order_date,
		o.customer_id,
		o.order_discount_cost,
		sum(o.order_discount_cost) over(partition by o.customer_id order by o.order_date asc
										rows between unbounded preceding and current row) as cum_sum_by_customers
from sales.orders o 

'''

# %%
orders = pd.read_csv("orders.csv", sep = '|') 

# Преобразуем дату в формат datetime
orders['order_date'] = pd.to_datetime(orders['order_date'])

# Сортируем по клиенту и дате заказа
orders = orders.sort_values(by=['customer_id', 'order_date'])

# Вычисляем накопительную сумму чеков по каждому клиенту
orders['cum_sum_by_customers'] = orders.groupby('customer_id')['order_discount_cost'].cumsum()

# Вывод результата
orders[['order_date', 'customer_id', 'order_discount_cost', 'cum_sum_by_customers']].head()
# Out:
#        order_date  customer_id  order_discount_cost  cum_sum_by_customers
# 239454 2022-05-23          332              68970.0               68970.0
# 452005 2022-05-28          332             395529.2              464499.2
# 574511 2022-06-01          332              62979.0              527478.2
# 79151  2022-10-15          332             471520.8              998999.0
# 177682 2022-12-22          332             269970.0             1268969.0

# %% [markdown]
# #### 7.7

# %% [markdown]
# В таблице stores проранжируйте магазины в зависимости от их площади. Самый большой по площади магазин должен получить ранг 1, если площадь у магазинов совпадает, то они должны получить одинаковые ранги, а последующие магазины ранг по порядку (без перескакивания).

# %%
sql = '''

select 
		s.store_uuid,
		s.city,
		s.area,
		dense_rank() over(order by s.area desc) as rank_by_area
from sales.stores s 

'''

# %%
stores = pd.read_csv("stores.csv", sep = '|')  

# Проранжируем магазины по площади (dense rank)
stores['rank_by_area'] = stores['area'].rank(method='dense', ascending=False)

# Вывод результата
stores[['store_uuid', 'city', 'area', 'rank_by_area']].sort_values(by = 'area', ascending = False).head()
# Out:
#                               store_uuid       city  area  rank_by_area
# 65  ffae0a23-e087-4f87-a16d-c9f8b28f1523    Иркутск   537           1.0
# 14  029c7595-9110-4b06-b941-e1c3db2ecf91    Саратов   533           2.0
# 67  5a6802d6-3995-4f3c-ad7a-9e44e08a06b7  Краснодар   524           3.0
# 21  ff935ec0-cb2e-4a61-8ecc-ccf09522ab76    Барнаул   521           4.0
# 72  5917d93d-f530-4612-864d-85dae6d3697c     Москва   520           5.0

# %% [markdown]
# #### 7.8

# %% [markdown]
# В таблице orders проранжируйте заказы для каждого клиента, отсортировав покупки по возрастанию даты. Иными словами, первый заказ должен получить ранг 1, если даты заказов совпадут, тогда высший ранг (с меньшим по модулю числом) должен получить заказ с большей суммой чека.

# %%
sql = '''

select 
		o.order_date,
		o.order_discount_cost,
		o.customer_id,
		row_number() over(partition by o.customer_id order by o.order_date asc, o.order_discount_cost desc) as order_rank
from sales.orders o

'''

# %%
orders = pd.read_csv("orders.csv", sep = '|')  

# Преобразуем дату в формат datetime
orders['order_date'] = pd.to_datetime(orders['order_date'])

# Сортируем по клиенту, дате заказа (по возрастанию) и сумме чека (по убыванию)
orders = orders.sort_values(by=['customer_id', 'order_date', 'order_discount_cost'], ascending=[True, True, False])

# Присваиваем ранг каждому заказу клиента
orders['order_rank'] = orders.groupby('customer_id').cumcount() + 1

# Вывод результата
orders[['order_date', 'order_discount_cost', 'customer_id', 'order_rank']].head()
# Out:
#        order_date  order_discount_cost  customer_id  order_rank
# 239454 2022-05-23              68970.0          332           1
# 452005 2022-05-28             395529.2          332           2
# 574511 2022-06-01              62979.0          332           3
# 79151  2022-10-15             471520.8          332           4
# 177682 2022-12-22             269970.0          332           5

# %% [markdown]
# #### 7.9

# %% [markdown]
# Для каждого клиента в таблице orders получите дату его предыдущего и последующего заказа (в двух разных столбцах).

# %%
sql = '''

select 
		o.customer_id,
		o.order_date,
		lag(o.order_date) over(partition by o.customer_id order by o.order_date asc) as lag_date,
		lead(o.order_date) over(partition by o.customer_id order by o.order_date asc) as lead_date
from sales.orders o 

'''

# %%
orders = pd.read_csv("orders.csv", sep = '|')  

# Преобразуем дату в формат datetime
orders['order_date'] = pd.to_datetime(orders['order_date'])

# Сортируем по клиенту и дате заказа
orders = orders.sort_values(by=['customer_id', 'order_date'])

# Вычисляем дату предыдущего и следующего заказа
orders['lag_date'] = orders.groupby('customer_id')['order_date'].shift(1)
orders['lead_date'] = orders.groupby('customer_id')['order_date'].shift(-1)

# Вывод результата
orders[['customer_id', 'order_date', 'lag_date', 'lead_date']].head()
# Out:
#         customer_id order_date   lag_date  lead_date
# 239454          332 2022-05-23        NaT 2022-05-28
# 452005          332 2022-05-28 2022-05-23 2022-06-01
# 574511          332 2022-06-01 2022-05-28 2022-10-15
# 79151           332 2022-10-15 2022-06-01 2022-12-22
# 177682          332 2022-12-22 2022-10-15 2023-01-27

# %% [markdown]
# #### 8.1

# %%
sql = '''

select 
		c.customer_id,
		c.customer_name, 
		count(o.check_id) as cnt_orders
from sales.orders o 
inner join sales.customers c on c.customer_id = o.customer_id 
where o.order_date between '2023-01-01' and '2023-12-31'
group by c.customer_id, c.customer_name 
having count(o.check_id) >= 15
order by count(o.check_id) desc, c.customer_id desc

'''

# %% [markdown]
# #### 8.2

# %%
sql = '''

select 
		s.city,
		c.category_name,
		sum(od.quantity) as sales,
		sum(od.discount_price)::int as revenue
from sales.order_details od 
inner join sales.orders o on o.check_id = od.check_id 
inner join sales.stores s on s.store_uuid = o.store_uuid 
inner join sales.products p on p.product_uuid = od.product_uuid 
inner join sales.categories c on c.category_id = p.category_id 
inner join sales.brands b on b.brand_id = p.brand_id 
where o.order_date between '2023-09-01' and '2023-12-31'
and s."class" = 'grand'
and b.brand_name in ('Xiaomi', 'Dell', 'Siemens', 'Logitech', 'HP', 'Sony', 'Nikon')
group by s.city, c.category_name
having sum(od.quantity) >= 100
order by s.city asc, sum(od.quantity) desc

'''

# %% [markdown]
# #### 8.3

# %%
sql = '''

select 
		s.salesman_id,
		s.salesman_name,
		s.date_of_employment,
		count(distinct od.product_uuid) as cnt_products
from sales.order_details od 
inner join sales.orders o on o.check_id = od.check_id 
inner join sales.salesmen s on s.salesman_id = o.salesman_id 
where o.order_date between '2023-04-01' and '2023-06-30'
group by s.salesman_id, s.salesman_name, s.date_of_employment
order by count(distinct od.product_uuid) desc
limit 5

'''

# %% [markdown]
# #### 8.4

# %%
sql = '''

select 
	    b.brand_name, 
	    avg(p1.price) as avg_price
from products p1
inner join products p2 on p1.brand_id <> p2.brand_id
inner join brands b on p1.brand_id = b.brand_id
group by b.brand_name
having avg(p1.price) > avg(p2.price)
order by avg(p1.price) desc

'''

# %% [markdown]
# #### 8.5

# %%
sql = '''

select 
		s.salesman_id,
		s.salesman_name,
		extract(month from s.date_of_employment) as month_of_employment,
		count(distinct o.check_id) as cnt_orders
from sales.orders o 
inner join sales.salesmen s on s.salesman_id = o.salesman_id 
							and extract(month from o.order_date) = extract(month from s.date_of_employment)
group by s.salesman_id,
		s.salesman_name, 
		extract(month from s.date_of_employment)
order by count(distinct o.check_id) desc

'''

# %% [markdown]
# #### 8.6

# %%
sql = '''

with first_date_in_category as (
								select 
										o.customer_id,
										p.category_id,
										min(o.order_date) as first_date
								from sales.order_details od 
								inner join sales.orders o on o.check_id = od.check_id 
								inner join sales.products p on p.product_uuid = od.product_uuid 
								group by o.customer_id, p.category_id 
)
select 
		o.customer_id, 
		p.category_id,
		count(distinct o.check_id) as cnt_orders
from sales.order_details od 
inner join sales.orders o on o.check_id = od.check_id  
inner join sales.products p on p.product_uuid = od.product_uuid 
inner join first_date_in_category f on o.customer_id = f.customer_id 
									and p.category_id = f.category_id 
									and (o.order_date > f.first_date and o.order_date <= f.first_date + 90)
group by o.customer_id, p.category_id 
having count(distinct o.check_id) > 2
order by count(distinct o.check_id) desc

'''

# %% [markdown]
# #### 8.7

# %%
sql = '''

select
    date_trunc('month', o.order_date) as month_,
    coalesce(100 * round(1 - sum(o.count_goods)::numeric / lag(sum(o.count_goods)) over(order by date_trunc('month', o.order_date)), 3), 0) as goods_growth_rate,
    coalesce(100 * round(1 - count(o.check_id)::numeric / lag(count(o.check_id)) over(order by date_trunc('month', o.order_date)), 3), 0) as orders_growth_rate,
    coalesce(100 * round(1 - (sum(o.order_discount_cost) / lag(sum(o.order_discount_cost)) over(order by date_trunc('month', o.order_date)))::numeric, 3), 0) as discount_growth_rate
from orders o
group by date_trunc('month', o.order_date)
order by date_trunc('month', o.order_date)

'''

# %% [markdown]
# #### 8.8

# %%
sql = '''

with unique_categories_per_check as (
    select 
	        o.check_id,
	        c.category_name,
	        o.customer_id,
	        o.order_date
    from sales.orders o
    inner join sales.order_details od on o.check_id = od.check_id
    inner join sales.products p on od.product_uuid = p.product_uuid
    inner join sales.categories c on p.category_id = c.category_id
    group by o.check_id,
	         c.category_name,
	         o.customer_id,
	         o.order_date
),
order_deltas as (
    select
        customer_id,
        category_name,
        order_date,
        order_date - lag(order_date) over(partition by customer_id, category_name order by order_date) as delta
    from unique_categories_per_check
)
select
    category_name,
    avg(delta) as avg_delta
from order_deltas
group by category_name
order by avg(delta) 

'''

# %% [markdown]
# #### 8.9

# %%
sql = '''

with table_1 as (
		  select 
			    o.check_id,
			    c.category_name,
			    sum(od.discount_price) as category_amount,
			    sum(sum(od.discount_price)) over (partition by o.check_id) as total_amount,
			    sum(od.discount_price)::numeric / sum(sum(od.discount_price)) over (partition by o.check_id) as category_share
		  from sales.orders o
		  inner join sales.order_details od on o.check_id = od.check_id
		  inner join sales.products p on od.product_uuid = p.product_uuid
		  inner join sales.categories c on p.category_id = c.category_id
		  where o.order_date between '2023-07-01' and '2023-09-30'
		  group by o.check_id, c.category_name
)
select
	  category_name,
	  avg(category_share) as avg_share
from table_1
group by category_name
order by avg(category_share) desc

'''

# %% [markdown]
# #### 8.10

# %%
sql = '''

select 
		distinct o.customer_id 
from sales.orders o
inner join sales.order_details od on o.check_id = od.check_id
where 1=1
and o.order_date between '2023-01-01' and '2023-12-31'
and od.product_uuid = '9ed16f97-d414-4162-b956-7fa9deb0f98b'  
intersect 
select 
		distinct o.customer_id 
from sales.orders o
inner join sales.order_details od on o.check_id = od.check_id
where 1=1
and o.order_date between '2023-01-01' and '2023-12-31'
and od.product_uuid in (
						'90f023dc-85f3-46d8-910f-b48e69ab9ce7',
						'54f244b4-355f-4930-896e-d5b490d4a405',
						'5453b51c-93fd-452e-94b9-9a93d0b249be')

'''

# %% [markdown]
# #### 8.11

# %%
sql = '''

select 
		distinct o.customer_id 
from sales.orders o
inner join sales.stores s on o.store_uuid = s.store_uuid 
where 1=1
and o.order_date between '2023-04-01' and '2023-06-30'
and s.city = 'Санкт-Петербург' 
and s.address = 'ул. Герцена, д. 11 к. 5/9' 
except 
select 
		distinct o.customer_id 
from sales.orders o
inner join sales.stores s on o.store_uuid = s.store_uuid 
where 1=1
and o.order_date between '2023-04-01' and '2023-06-30'
and s.city = 'Санкт-Петербург' 
and s.address != 'ул. Герцена, д. 11 к. 5/9'

'''

# %% [markdown]
# #### 8.12

# %% [markdown]
# ....
