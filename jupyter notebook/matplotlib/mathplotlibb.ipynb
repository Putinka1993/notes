# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.ticker import AutoMinorLocator
from matplotlib.gridspec import GridSpec
from sklearn.datasets import load_iris

# %%
# 🎨 1. Построение простого графика

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)          # Строим линию по точкам x и y
plt.title("Простой график")    # Заголовок
plt.xlabel("ось X")     # Подпись оси X
plt.ylabel("ось Y")     # Подпись оси Y
plt.grid(True)          # Включаем сетку
plt.show()              # Отображение графика

# %%
# 🎨 2. Несколько графиков на одном поле

# %%
plt.plot(x, y, label="Первая линия")
plt.plot(x, [i*2 for i in y], label="Вторая линия", linestyle='--')

plt.legend()            # Легенда графика
plt.show()

# %%
# 🧩 3. Изменение стиля линии и маркеров

# %%
plt.plot(x, y, color='red', linestyle='-.', marker='o', linewidth=2)

# %%
# 🧱 4. Диаграмма разброса (scatter plot)

# %%
plt.scatter(x, y, color='green', s=100)  # s — размер точек

# %%
# 📊 5. Столбчатая диаграмма (bar chart)

# %%
plt.bar(x, y, color='orange', width=0.5)
# Out:
# <BarContainer object of 4 artists>

# %%
# 6. Гистограмма (histogram)

# %%
data = [1, 1, 2, 2, 2, 3, 4, 5, 5, 5, 5, 6, 7]

plt.hist(data, bins=5, color='purple', edgecolor='black')
# Out:
# (array([5., 1., 1., 4., 2.]),
#  array([1. , 2.2, 3.4, 4.6, 5.8, 7. ]),
#  <BarContainer object of 5 artists>)

# %%
# 🧼 7. Несколько графиков (Subplots)

# %%
plt.subplot(1, 2, 1)  # 1 строка, 2 столбца, 1-я панель
plt.plot(x, y)

plt.subplot(1, 2, 2)  # 2-я панель
plt.bar(x, y)

plt.tight_layout()    # Автоматическая компоновка
plt.show()

# %%
# 💾 8. Сохранение графика в файл

# %%
# plt.savefig("graph.png", dpi=300)  # Можно задать формат и качество

# %%
x = np.linspace(-np.pi, np.pi, 20)
cos_x = np.cos(x) 
sin_x = np.sin(x)

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_axes([0, 0, 1, 1])

ax1 = ax.plot(x, cos_x, marker='o', c='c', linewidth=2) 
ax2 = ax.plot(x, sin_x, marker='*', c='r', linewidth=2)

ax.legend(labels=['cos(x)', 'sin(x)']) 
ax.grid(alpha=0.3)

ax.set_title('Графики тригонометрических функций')

plt.show()

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_axes([0, 0, 1, 1])

ax1 = ax.plot(x, cos_x, marker='o', c='c', linewidth=2) 
ax2 = ax.plot(x, sin_x, marker='*', c='r', linewidth=2)

ax.legend(labels=['cos(x)', 'sin(x)']) 
ax.grid(alpha=0.3)

ax.set_title('Графики тригонометрических функций', fontsize=15, fontweight ='bold', color='c')

plt.show()

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_axes([0, 0, 1, 1])

ax1 = ax.plot(x, cos_x, marker='o', c='c', linewidth=2) 
ax2 = ax.plot(x, sin_x, marker='*', c='r', linewidth=2)

ax.legend(labels=['cos(x)', 'sin(x)']) 
ax.grid(alpha=0.3)

ax.set_title('Графики тригонометрических функций', fontsize=15, fontweight ='bold', color='c', pad=15,
             loc='left')

plt.show()

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_axes([0, 0, 1, 1])

ax1 = ax.plot(x, cos_x, marker='o', c='c', linewidth=2) 
ax2 = ax.plot(x, sin_x, marker='*', c='r', linewidth=2)

ax.legend(labels=['cos(x)', 'sin(x)']) 
ax.grid(alpha=0.3)

ax.set_title('Графики тригонометрических\nфункций для демонстрации\nработы функции Axes.set_title()', 
             fontsize=14, pad=15)

plt.show()

# %%
x = np.linspace(-np.pi, np.pi, 20)
cos_x = np.cos(x) 
sin_x = np.sin(x)

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_axes([0, 0, 1, 1])

ax1 = ax.plot(x, cos_x, marker='o', c='c', linewidth=2) 
ax2 = ax.plot(x, sin_x, marker='*', c='r', linewidth=2)

ax.legend(labels=['cos(x)', 'sin(x)']) 
ax.grid(alpha=0.3)
ax.set_title('Графики тригонометрических функций')
ax.set_xlabel('х')
ax.set_ylabel('Функция от х')

plt.show()

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_axes([0, 0, 1, 1])

ax1 = ax.plot(x, cos_x, marker='o', c='c', linewidth=2) 
ax2 = ax.plot(x, sin_x, marker='*', c='r', linewidth=2)

ax.legend(labels=['cos(x)', 'sin(x)']) 
ax.grid(alpha=0.3)
ax.set_title('Графики тригонометрических функций')
ax.set_xlabel('х')
ax.set_ylabel('Функция от х')

ax.set_xlim(-4, 4)
ax.set_ylim(-1.5, 1.5)

plt.show()

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_axes([0, 0, 1, 1])

ax1 = ax.plot(x, cos_x, marker='o', c='c', linewidth=2) 
ax2 = ax.plot(x, sin_x, marker='*', c='r', linewidth=2)

ax.tick_params(direction='inout')
ax.tick_params(labelcolor='green', labelsize=20)

plt.show()

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_axes([0, 0, 1, 1])

ax1 = ax.plot(x, cos_x, marker='o', c='c', linewidth=2) 
ax2 = ax.plot(x, sin_x, marker='*', c='r', linewidth=2)

plt.show()

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_axes([0, 0, 1, 1])

ax1 = ax.plot(x, cos_x, marker='o', c='c', linewidth=2) 
ax2 = ax.plot(x, sin_x, marker='*', c='r', linewidth=2)

ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

plt.show()

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_axes([0, 0, 1, 1])

ax1 = ax.plot(x, cos_x, marker='o', c='c', linewidth=2) 
ax2 = ax.plot(x, sin_x, marker='*', c='r', linewidth=2)

ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.tick_params(which='major', axis='x', pad=10)
ax.tick_params(which='minor', labelsize=7)
ax.xaxis.set_minor_formatter('{x:.1f}')

plt.show()

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_axes([0, 0, 1, 1])

ax1 = ax.plot(x, cos_x, marker='o', c='c', linewidth=2) 
ax2 = ax.plot(x, sin_x, marker='*', c='r', linewidth=2)

ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.tick_params(which='major', axis='x', pad=10)
ax.tick_params(which='minor', labelsize=7, grid_alpha=0.2)
ax.xaxis.set_minor_formatter('{x:.1f}')
ax.grid(which='both')

plt.show()

# %%
x = np.linspace(0, 10, 5)
y1 = x**2
y2 = x**3
y3 = x**0.5
y4 = np.sin(x**2)

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)

plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

ax[0, 0].plot(x, y1, 'r')
ax[0, 1].plot(x, y2, 'b')
ax[1, 0].plot(x, y3, 'g')
ax[1, 1].plot(x, y4, 'c')

plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 5))

ax[0, 0].plot(x, y1, 'r')
ax[0, 1].plot(x, y2, 'b')
ax[1, 0].plot(x, y3, 'g')
ax[1, 1].plot(x, y4, 'c')

ax[0, 0].grid()
ax[0, 1].grid()
ax[1, 0].grid()
ax[1, 1].grid()

plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 5))

ax[0, 0].plot(x, y1, 'r')
ax[0, 1].plot(x, y2, 'b')
ax[1, 0].plot(x, y3, 'g')
ax[1, 1].plot(x, y4, 'c')

ax[0, 0].set_title('y1')
ax[0, 1].set_title('y2')
ax[1, 0].set_title('y3')
ax[1, 1].set_title('y4')

fig.suptitle('Графики')

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(10, 5))

gs = GridSpec(nrows=2, ncols=2, figure=fig)

ax1 = fig.add_subplot(gs[0,0])
ax2 = fig.add_subplot(gs[0,1])
ax3 = fig.add_subplot(gs[1,0])
ax4 = fig.add_subplot(gs[1,1])

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(10, 5))

gs = GridSpec(nrows=3, ncols=3, figure=fig)

ax1 = fig.add_subplot(gs[0,0])
ax2 = fig.add_subplot(gs[0,1])
ax3 = fig.add_subplot(gs[0,2])
ax4 = fig.add_subplot(gs[1:,0:2])

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(10, 5))

widths = [1, 3]
heights = [1, 2]

gs = GridSpec(nrows=2, ncols=2, figure=fig, width_ratios=widths, height_ratios=heights)

ax1 = fig.add_subplot(gs[0,0])
ax2 = fig.add_subplot(gs[0,1])
ax3 = fig.add_subplot(gs[1,0])
ax4 = fig.add_subplot(gs[1,1])

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(10, 5))

widths = [1, 2, 1]
heights = [1, 2, 1]

gs = GridSpec(nrows=3, ncols=3, figure=fig, width_ratios=widths, height_ratios=heights)

ax1 = fig.add_subplot(gs[0,0])
ax2 = fig.add_subplot(gs[0,1])
ax3 = fig.add_subplot(gs[1,0])
ax4 = fig.add_subplot(gs[1,1])
ax5 = fig.add_subplot(gs[:,2])
ax6 = fig.add_subplot(gs[2,0:2])

plt.tight_layout()
plt.show()

# %%
iris_dataset = load_iris()
df = pd.DataFrame(iris_dataset['data'], columns=iris_dataset['feature_names'])
df['target'] = iris_dataset['target']
df['target'] = df['target'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})

display(df)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#         target
# 0       setosa
# ...

# %%
x = df['petal length (cm)']
y = df['petal width (cm)']

plt.scatter(x, y)

plt.xlabel('Длина лепестка')
plt.ylabel('Ширина лепестка')

plt.show()

# %%
plt.scatter(x='petal length (cm)', y='petal width (cm)', data=df)

plt.xlabel('Длина лепестка')
plt.ylabel('Ширина лепестка')

plt.show()

# %%
x1 = df[df['target'] == 'setosa']['petal length (cm)']
y1 = df[df['target'] == 'setosa']['petal width (cm)']

x2 = df[df['target'] == 'versicolor']['petal length (cm)']
y2 = df[df['target'] == 'versicolor']['petal width (cm)']

x3 = df[df['target'] == 'virginica']['petal length (cm)']
y3 = df[df['target'] == 'virginica']['petal width (cm)']

fig, ax = plt.subplots()

ax.scatter(x1, y1, label='setosa', edgecolor='black')
ax.scatter(x2, y2, label='versicolor')
ax.scatter(x3, y3, label='virginica')

plt.legend()
plt.xlabel('Длина лепестка')
plt.ylabel('Ширина лепестка')

plt.show()

# %%
x1 = df[df['target'] == 'setosa']['petal length (cm)']
y1 = df[df['target'] == 'setosa']['petal width (cm)']

x2 = df[df['target'] == 'versicolor']['petal length (cm)']
y2 = df[df['target'] == 'versicolor']['petal width (cm)']

x3 = df[df['target'] == 'virginica']['petal length (cm)']
y3 = df[df['target'] == 'virginica']['petal width (cm)']

fig, ax = plt.subplots()

ax.scatter(x1, y1, label='setosa', edgecolor='black')
ax.scatter(x2, y2, label='versicolor', linewidth=0.5)
ax.scatter(x3, y3, label='virginica', alpha=0.3)

plt.legend()
plt.xlabel('Длина лепестка')
plt.ylabel('Ширина лепестка')

plt.show()

# %%
x = df['petal length (cm)']
y = df['petal width (cm)']
z = df['sepal width (cm)'] / df['sepal length (cm)']

plt.scatter(x, y, c=z, cmap='PuOr_r')
plt.xlabel('Длина лепестка')
plt.ylabel('Ширина лепестка')

cbar = plt.colorbar()
cbar.set_label('Отношение ширины чашелистика к его длине')

plt.show()

# %%
x1 = [10,15,16,11,17,16,14,13,12]
y1 = [ 1, 3, 4, 2, 1, 5, 4, 3, 5]
x2 = [20,25,23,24,26,21,22,23,22]
y2 = [ 8,10, 9,11,12,10,14,10,13]
x3 = [26,30,24,28,24,28,31,32,27]
y3 = [ 3, 4, 6, 8, 7, 6, 8, 9, 2]

plt.scatter(x1, y1, marker='D', edgecolor='k')
plt.scatter(x2, y2, marker='P')
plt.scatter(x3, y3, marker='X')

plt.show()
