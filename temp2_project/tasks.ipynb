# %% [markdown]
# # 🎯 ЗАДАНИЕ: Анализ деятельности IT-фирмы на основе расходов и сервисов
#
# # Цель: Научиться работать с корпоративными данными (расходы, департаменты, услуги),
# понять структуру затрат IT-компании и построить аналитику в Power BI.
#
# ⸻
#
# ## 📌 Этап 1. Подготовка и исследование структуры данных
#
# **Цель:** Разобраться, какие у нас есть таблицы и поля, проверить качество данных.
#
# ✅ Шаги:
# - Изучить схему данных: `expenses`, `departments`, `services`, `employees`.
# - Выполнить SQL-запросы:
#   - Посмотреть первые 10 строк из каждой таблицы (`SELECT TOP 10 *`).
#   - Проверить количество строк и наличие `NULL`.
#   - Убедиться, что связи между таблицами работают (например, `JOIN expenses e ON e.id_department = d.id_department`).
# - Проверить даты (`date`): нет ли некорректных значений.
# - Посмотреть распределение по типам расходов (`expense_type`).
#
# 📊 Инструменты: SQL Server / PostgreSQL (или SQLite), базовые запросы.
#
# ⸻
#
# ## 📌 Этап 2. Базовый анализ расходов
#
# **Цель:** Получить представление о том, на что фирма тратит деньги.
#
# ✅ Шаги:
# - SQL-запросы:
#   - Общая сумма расходов.
#   - Сумма расходов по департаментам.
#   - Сумма расходов по типам (`электричество`, `ПО`, `аренда` и т.д.).
#   - Сумма расходов по месяцам.
# - В Power BI:
#   - Построить график расходов по месяцам.
#   - Построить диаграмму расходов по типам.
#   - Построить столбчатую диаграмму “департамент vs сумма”.
#
# 📊 Инструменты: SQL для агрегации, Power BI для визуализаций.
#
# ⸻
#
# ## 📌 Этап 3. Анализ по услугам и сотрудникам
#
# **Цель:** Понять, какие сервисы и сотрудники связаны с наибольшими затратами.
#
# ✅ Шаги:
# - SQL-запросы:
#   - Топ-5 сервисов по сумме расходов.
#   - Средний расход на одного сотрудника.
#   - Расходы в разрезе сервисов и департаментов.
# - В Power BI:
#   - Визуализация “сервис vs расходы”.
#   - Карточка с метрикой: “средний расход на сотрудника”.
#   - Heatmap: департамент × сервис (по расходам).
#
# 📊 Инструменты: SQL для джойнов и группировок, Power BI для интерактивных дашбордов.
#
# ⸻
#
# ## 📌 Этап 4. Динамика и тренды
#
# **Цель:** Выявить, как расходы меняются во времени.
#
# ✅ Шаги:
# - SQL-запросы:
#   - Расходы по кварталам/годам.
#   - Сравнение текущего года с предыдущим.
# - В Power BI:
#   - Линейный график: динамика расходов по месяцам.
#   - Срезы (slicers) для выбора департамента или типа расходов.
#   - KPI-карточки: рост/падение расходов в процентах.
#
# 📊 Инструменты: временные агрегации в SQL, Power BI time intelligence.
#
# ⸻
#
# ## 📌 Этап 5. Финальные инсайты и презентация
#
# **Цель:** Сформулировать выводы, как настоящий аналитик.
#
# ✅ Шаги:
# - Ответить на вопросы:
#   - Какой департамент тратит больше всего?
#   - На какие категории уходит основная часть бюджета?
#   - Какие сервисы самые затратные?
#   - Как менялись расходы во времени?
# - В Power BI:
#   - Собрать итоговый дашборд с 4–5 ключевыми визуализациями.
#   - Добавить фильтры по департаменту, типу расходов, периоду.
# - Подготовить слайды/отчёт с инсайтами и рекомендациями для руководства.
#
# 📢 Сделай:
# - Финальный Power BI дашборд.
# - PDF/слайды с выводами и скриншотами графиков.
#
# ⸻
#
# ## 💡 Советы:
# - Старайся сначала делать простые SQL-запросы и проверять данные “вручную”.
# - Визуализации должны отвечать на конкретные бизнес-вопросы.
# - Не перегружай дашборд — лучше 4–5 ключевых метрик.
# - Думай как аналитик: что важно для руководства компании?
